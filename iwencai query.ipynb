# %%
df_1=query_iwencai("成交额排序,前3个交易日区间涨幅在-10%和15%之间，10日均线斜率大于-5，前三个交易日区间涨幅，后一个交易日最大涨幅，涨跌幅")
df_1
# Out:
#            股票代码  股票简称  区间涨跌幅:前复权    均线角度    最大涨幅 涨跌幅:前复权             成交额  \
# 0     300750.SZ  宁德时代  -4.038870  57.074  14.968  14.462  13248182800.00
# 1     601127.SH   赛力斯   4.505495  67.715   9.243   7.466   8705030700.00
# 2     601138.SH  工业富联   9.318681  75.672   7.559   3.820   8195001200.00
# 3     603019.SH  中科曙光   0.396675  69.396   3.707   3.707   7670789400.00
# 4     301236.SZ  软通动力   0.250627  72.685  16.417  14.396   5880365900.00
# ...         ...   ...        ...     ...     ...     ...             ...
# 3630  832110.BJ  雷特科技   0.962627   6.446   0.953   0.953      2603055.00
# 3631  839792.BJ  东和新材  -0.474684   7.933   2.385   2.226      2532083.00
# 3632  836419.BJ  万德股份  -1.688782  19.872   1.104   0.982      2469298.00
# 3633  833455.BJ  汇隆活塞   1.542416   0.000   1.013   0.760      2258920.00
# 3634  603117.SH  ST万林   0.611621   1.747   0.608   0.000      1938115.80
#
#           成交额排名  成交额排名名次  成交额排名基数
# 0        1/5353        1     5353
# ...

# %%
df_1.to_excel('股票列表.xlsx',index=False,engine='openpyxl')
